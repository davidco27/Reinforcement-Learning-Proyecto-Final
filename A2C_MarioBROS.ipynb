# %%
# !pip install "gymnasium[accept-rom-license]"
# Out:
# Requirement already satisfied: gymnasium[accept-rom-license] in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[accept-rom-license]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[accept-rom-license]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Requirement already satisfied: autorom~=0.4.2 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (0.4.2)
# Requirement already satisfied: click in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (4.65.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (0.6.1)
# Requirement already satisfied: colorama in c:\users\raul\appdata\roaming\python\python311\site-packages (from click->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2024.2.2)

# %%
# !pip install "gymnasium[atari]"
# !pip install stable_baselines3
# !pip install stable-baselines[mpi]
# Out:
# Requirement already satisfied: gymnasium[atari] in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[atari]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[atari]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[atari]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: shimmy<1.0,>=0.1.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.2.1)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (0.8.1)
# Requirement already satisfied: importlib-resources in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari]) (6.1.1)
# Requirement already satisfied: stable_baselines3 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (1.23.5)
# Requirement already satisfied: torch>=1.13 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (2.2.0)
# Requirement already satisfied: cloudpickle in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable_baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from torch>=1.13->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from torch>=1.13->stable_baselines3) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from pandas->stable_baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Collecting stable-baselines[mpi]
#   Using cached stable_baselines-2.10.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gym>=0.11 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gym[atari,classic_control]>=0.11->stable-baselines[mpi]) (0.26.2)
# Requirement already satisfied: scipy in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (1.11.4)
# Requirement already satisfied: joblib in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (1.2.0)
# Requirement already satisfied: cloudpickle>=0.5.5 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (3.0.0)
# Requirement already satisfied: opencv-python in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (4.9.0.80)
# Requirement already satisfied: numpy in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (1.23.5)
# Requirement already satisfied: pandas in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from stable-baselines[mpi]) (3.8.0)
# Collecting mpi4py (from stable-baselines[mpi])
#   Using cached mpi4py-3.1.6-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gym>=0.11->gym[atari,classic_control]>=0.11->stable-baselines[mpi]) (0.0.8)
# Requirement already satisfied: ale-py~=0.8.0 in c:\users\raul\.conda\envs\noestructurados\lib\site-packages (from gym[atari,classic_control]>=0.11->stable-baselines[mpi]) (0.8.1)
# Collecting pygame==2.1.0 (from gym[atari,classic_control]>=0.11->stable-baselines[mpi])
#   Using cached pygame-2.1.0.tar.gz (5.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [77 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using WINDOWS configuration...
#
#       Making dir :prebuilt_downloads:
#       Downloading... https://www.libsdl.org/release/SDL2-devel-2.0.16-VC.zip 13d952c333f3c2ebe9b7bc0075b4ad2f784e7584
#       Unzipping :prebuilt_downloads\SDL2-devel-2.0.16-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_image/release/SDL2_image-devel-2.0.5-VC.zip 137f86474691f4e12e76e07d58d5920c8d844d5b
#       Unzipping :prebuilt_downloads\SDL2_image-devel-2.0.5-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_ttf/release/SDL2_ttf-devel-2.0.15-VC.zip 1436df41ebc47ac36e02ec9bda5699e80ff9bd27
#       Unzipping :prebuilt_downloads\SDL2_ttf-devel-2.0.15-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_mixer/release/SDL2_mixer-devel-2.0.4-VC.zip 9097148f4529cf19f805ccd007618dec280f0ecc
#       Unzipping :prebuilt_downloads\SDL2_mixer-devel-2.0.4-VC.zip:
#       Downloading... https://www.pygame.org/ftp/jpegsr9d.zip ed10aa2b5a0fcfe74f8a6f7611aeb346b06a1f99
#       Unzipping :prebuilt_downloads\jpegsr9d.zip:
#       Downloading... https://pygame.org/ftp/prebuilt-x64-pygame-1.9.2-20150922.zip 3a5af3427b3aa13a0aaf5c4cb08daaed341613ed
#       Unzipping :prebuilt_downloads\prebuilt-x64-pygame-1.9.2-20150922.zip:
#       copying into .\prebuilt-x64
#       Path for SDL: prebuilt-x64\SDL2-2.0.16
#       ...Library directory for SDL: prebuilt-x64/SDL2-2.0.16/lib/x64
#       ...Include directory for SDL: prebuilt-x64/SDL2-2.0.16/include
#       Path for FONT: prebuilt-x64\SDL2_ttf-2.0.15
#       ...Library directory for FONT: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64
#       ...Include directory for FONT: prebuilt-x64/SDL2_ttf-2.0.15/include
#       Path for IMAGE: prebuilt-x64\SDL2_image-2.0.5
#       ...Library directory for IMAGE: prebuilt-x64/SDL2_image-2.0.5/lib/x64
#       ...Include directory for IMAGE: prebuilt-x64/SDL2_image-2.0.5/include
#       Path for MIXER: prebuilt-x64\SDL2_mixer-2.0.4
#       ...Library directory for MIXER: prebuilt-x64/SDL2_mixer-2.0.4/lib/x64
#       ...Include directory for MIXER: prebuilt-x64/SDL2_mixer-2.0.4/include
#       Path for PORTMIDI: prebuilt-x64
#       ...Library directory for PORTMIDI: prebuilt-x64/lib
#       ...Include directory for PORTMIDI: prebuilt-x64/include
#       DLL for SDL2: prebuilt-x64/SDL2-2.0.16/lib/x64/SDL2.dll
#       DLL for SDL2_ttf: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64/SDL2_ttf.dll
#       DLL for SDL2_image: prebuilt-x64/SDL2_image-2.0.5/lib/x64/SDL2_image.dll
#       DLL for SDL2_mixer: prebuilt-x64/SDL2_mixer-2.0.4/lib/x64/SDL2_mixer.dll
#       DLL for portmidi: prebuilt-x64/lib/portmidi.dll
#       Path for FREETYPE not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       Path for PNG not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       Path for JPEG not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       DLL for freetype: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64/libfreetype-6.dll
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/CompileWindows
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\setup.py", line 388, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\buildconfig\config.py", line 234, in main
#           deps = CFG.main(**kwds)
#                  ^^^^^^^^^^^^^^^^
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\buildconfig\config_win.py", line 511, in main
#           return setup_prebuilt_sdl2(prebuilt_dir)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\buildconfig\config_win.py", line 471, in setup_prebuilt_sdl2
#           DEPS.configure()
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\buildconfig\config_win.py", line 336, in configure
#           from . import vstools
#         File "C:\Users\raul\AppData\Local\Temp\pip-install-kivx839h\pygame_9ee3231978b44e82a156e2382870fce8\buildconfig\vstools.py", line 11, in <module>
#           compiler.initialize()
#         File "C:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\setuptools\_distutils\msvc9compiler.py", line 403, in initialize
#           vc_env = query_vcvarsall(VERSION, plat_spec)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\setuptools\_distutils\msvc9compiler.py", line 281, in query_vcvarsall
#           raise DistutilsPlatformError("Unable to find vcvarsall.bat")
#       distutils.errors.DistutilsPlatformError: Unable to find vcvarsall.bat
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Common imports
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# To get smooth animations
import matplotlib.animation as animation
mpl.rc('animation', html='jshtml')
import ale_py
import shimmy
import numpy as np
import os
import gymnasium as gym
from gym import spaces
from stable_baselines3 import A2C
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
#from stable_baselines3.common.policies import MlpPolicy

# %%
env = gym.make("ALE/MarioBros-v5",render_mode="rgb_array")

# %%
n_actions = 18

action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
param_noise = None

model = A2C("MlpPolicy", env)
model.learn(total_timesteps=10000, log_interval=4)

# %%
model.save("A2C_MARIOBROS")

# %%
model = A2C.load("A2C_MARIOBROS")
obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 obs, info = env.reset()
#       3 while True:
# ----> 4     action, _states = model.predict(obs, deterministic=True)
#       5     obs, reward, terminated, truncated, info = env.step(action)
#       6     if terminated or truncated:
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\policies.py:717, in ActorCriticPolicy._predict(self, observation, deterministic)
#     709 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     710     """
#     711     Get the action according to the policy for a given observation.
#     712
#    (...)
#     715     :return: Taken action according to the policy
#     716     """
# --> 717     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\policies.py:752, in ActorCriticPolicy.get_distribution(self, obs)
#     750 features = super().extract_features(obs, self.pi_features_extractor)
#     751 latent_pi = self.mlp_extractor.forward_actor(features)
# --> 752 return self._get_action_dist_from_latent(latent_pi)
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\policies.py:697, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
# --> 697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     698 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     699     # Here mean_actions are the flattened logits
#     700     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\stable_baselines3\common\distributions.py:288, in CategoricalDistribution.proba_distribution(self, action_logits)
#     287 def proba_distribution(self: SelfCategoricalDistribution, action_logits: th.Tensor) -> SelfCategoricalDistribution:
# --> 288     self.distribution = Categorical(logits=action_logits)
#     289     return self
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\torch\distributions\categorical.py:70, in Categorical.__init__(self, probs, logits, validate_args)
#      66 self._num_events = self._param.size()[-1]
#      67 batch_shape = (
#      68     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      69 )
# ---> 70 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\torch\distributions\distribution.py:66, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      64     continue  # skip checking lazily-constructed args
#      65 value = getattr(self, param)
# ---> 66 valid = constraint.check(value)
#      67 if not valid.all():
#      68     raise ValueError(
#      69         f"Expected parameter {param} "
#      70         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73         f"but found invalid values:\n{value}"
#      74     )
#
# File c:\Users\raul\.conda\envs\noestructurados\Lib\site-packages\torch\distributions\constraints.py:221, in _IndependentConstraint.check(self, value)
#     219 def check(self, value):
#     220     result = self.base_constraint.check(value)
# --> 221     if result.dim() < self.reinterpreted_batch_ndims:
#     222         expected = self.base_constraint.event_dim + self.reinterpreted_batch_ndims
#     223         raise ValueError(
#     224             f"Expected value.dim() >= {expected} but got {value.dim()}"
#     225         )
#
# KeyboardInterrupt:

# %%
episodes = 10

for ep in range(episodes):
    obs = env.reset()
    obs = obs[0]
    done = False
    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, tr, info = env.step(action)
        env.render()
        print(rewards)
